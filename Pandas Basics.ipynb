# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx')

# %%
type(df)  # DataFrame is table
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
# We can read data from any sheet by using sheet_name = " Sheet name"
pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx', sheet_name= 'Sheet2')
# Out:
#          Day       Date  Customer Visited    Rush
# 0     Monday 2023-06-12                10     Low
# 1    Tuesday 2023-06-13                10     Low
# 2  Wednesday 2023-06-14                15  Medium
# 3   Thursday 2023-06-15                11     Low
# 4     Friday 2023-06-16                25  Medium
# 5   Saturday 2023-06-17                54    high
# 6     Sunday 2023-06-18                74    high

# %%
pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx', sheet_name= 'Sheet3')
# Out:
#   Column Name 1 Column Name 2     Column Name 3     Column Name 4
# 0         Data1        Data A   Other Data Set1  Other Data Set A
# 1         Data2        Data B   Other Data Set2  Other Data Set B
# 2         Data3        Data C   Other Data Set3  Other Data Set C
# 3         Data4        Data D   Other Data Set4  Other Data Set D
# 4         Data5        Data E   Other Data Set5  Other Data Set E
# 5         Data6        Data F   Other Data Set6  Other Data Set F
# 6         Data7        Data G   Other Data Set7  Other Data Set G
# 7         Data8        Data H   Other Data Set8  Other Data Set H
# 8         Data9        Data I   Other Data Set9  Other Data Set I
# 9        Data10        Data J  Other Data Set10  Other Data Set J

# %%
# By default 1st row of every table considered as header, in case if we want to remove header then we need to choose header = None

# %%
pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx', sheet_name= 'Sheet3', header = None )
# Out:
#                 0              1                 2                 3
# 0   Column Name 1  Column Name 2     Column Name 3     Column Name 4
# 1           Data1         Data A   Other Data Set1  Other Data Set A
# 2           Data2         Data B   Other Data Set2  Other Data Set B
# 3           Data3         Data C   Other Data Set3  Other Data Set C
# 4           Data4         Data D   Other Data Set4  Other Data Set D
# 5           Data5         Data E   Other Data Set5  Other Data Set E
# 6           Data6         Data F   Other Data Set6  Other Data Set F
# 7           Data7         Data G   Other Data Set7  Other Data Set G
# 8           Data8         Data H   Other Data Set8  Other Data Set H
# 9           Data9         Data I   Other Data Set9  Other Data Set I
# 10         Data10         Data J  Other Data Set10  Other Data Set J

# %%
# if we want to give column name by ourself use names = ['A', 'B','C']

# %%
pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx', sheet_name= 'Sheet3', header = None, names =  ['A', "B",'C'])
# Out:
#                            A                 B                 C
# Column Name 1  Column Name 2     Column Name 3     Column Name 4
# Data1                 Data A   Other Data Set1  Other Data Set A
# Data2                 Data B   Other Data Set2  Other Data Set B
# Data3                 Data C   Other Data Set3  Other Data Set C
# Data4                 Data D   Other Data Set4  Other Data Set D
# Data5                 Data E   Other Data Set5  Other Data Set E
# Data6                 Data F   Other Data Set6  Other Data Set F
# Data7                 Data G   Other Data Set7  Other Data Set G
# Data8                 Data H   Other Data Set8  Other Data Set H
# Data9                 Data I   Other Data Set9  Other Data Set I
# Data10                Data J  Other Data Set10  Other Data Set J

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head(2)  #1st 2 records
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head() # will give 1st 5 records
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail() # will give last 5 records
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(2) #last 2 records
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
#comma seprayed values -->csv file

# %%
pd.read_csv (r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\haberman.csv', header = None, names = ['Age of patient', "Patient's year of operation", 'Number of positive axillary nodes detected', 'Survival status '])
# Out:
#      Age of patient  Patient's year of operation  \
# 0                30                           64
# 1                30                           62
# 2                30                           65
# 3                31                           59
# 4                31                           65
# ..              ...                          ...
# 301              75                           62
# 302              76                           67
# 303              77                           65
# 304              78                           65
# 305              83                           58
#
#      Number of positive axillary nodes detected  Survival status
# 0                                             1                 1
# 1                                             3                 1
# 2                                             0                 1
# 3                                             2                 1
# ...

# %%
pd.read_csv('haberman1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %%
pd.read_csv('haberman1.csv', sep= '@') # we can seprate this data
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')

# %%
a = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
len(a)  #here its showing numbers of table
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'torokati44', 'id': 288816, 'node_id...
# 1     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3     {'login': 'jorisvandenbossche', 'id': 1020496,...
# 4     {'login': 'eirki', 'id': 13980742, 'node_id': ...
# 5     {'login': 'arnaudlegout', 'id': 7670869, 'node...
# 6     {'login': 'dependabot[bot]', 'id': 49699333, '...
# 7     {'login': 'wence-', 'id': 1126981, 'node_id': ...
# 8     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 9     {'login': 'ABizzinotto', 'id': 40039437, 'node...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'chrimaho', 'id': 44449504, 'node_id...
# 12    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 13    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 14    {'login': 'jrowley8013', 'id': 55408699, 'node...
# 15    {'login': 'tpaxman', 'id': 39451402, 'node_id'...
# 16    {'login': 'Charlie-XIAO', 'id': 108576690, 'no...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'torokati44',
#  'id': 288816,
#  'node_id': 'MDQ6VXNlcjI4ODgxNg==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/288816?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/torokati44',
#  'html_url': 'https://github.com/torokati44',
#  'followers_url': 'https://api.github.com/users/torokati44/followers',
#  'following_url': 'https://api.github.com/users/torokati44/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/torokati44/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/torokati44/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/torokati44/subscriptions',
#  'organizations_url': 'https://api.github.com/users/torokati44/orgs',
#  'repos_url': 'https://api.github.com/users/torokati44/repos',
#  'events_url': 'https://api.github.com/users/torokati44/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/torokati44/received_events',
#  'type': 'User',
# ...

# %%
df = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
#conversion of df in jason file
df.to_json('dftest.json')

# %%
pwd # location of file
# Out:
# 'C:\\Users\\Lenovo'

# %%
#Save data Permanently in file
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv('C:\\Users\\Lenovo\\dftest1.csv')

# %%
df.to_csv('C:\\Users\\Lenovo\\dftest123.csv', sep = "#")

# %%
df.to_csv('C:\\Users\\Lenovo\\dftest1234.csv', index= False)  # if we don't want indexes in table

# %%
df_salesdata = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data set\Dress Sales.xlsx')

# %%
df_salesdata.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# 0  1006032852       2114       2274                 2491                 2660
# 1  1212192089        151        275                  570                  750
# 2  1190380701          6          7                    7                    7
# 3   966005983       1005       1128                 1326                 1455
# 4   876339541        996       1175                 1304                 1396
#
#    2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# 0                 2727                 2887                 2930
# 1                  813                 1066                 1164
# 2                    8                    8                    9
# 3                 1507                 1621                 1637
# 4                 1432                 1559                 1570
#
#   2013-12-09 00:00:00 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013 30/9/2013  \
# ...

# %%
df_salesdata.isnull().sum()
# Out:
# Dress_ID                 0
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64
