# %%
Superstore USA
1 . Load this data in SQL and in pandas with a relation in SQL 
2 . While loading this data you don’t have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how many return that we have received and with a product id 
4 . Try to join order and return data both in SQL and pandas 
5 . Try to find out how many unique customers that we have 
6 . Try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . Find out how many different shipment modes that we have and what is a percentage usability of all the shipment mode with respect to dataset 
8 . Create a new column and try to find out a difference between order date and shipment date
9 . Based on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which shipment duration was more than 15 days and find out that region manager as well 
11 . Group by region and find out which region is more profitable 
12 . Try to find out overall in which country we are giving more discount 
13 . Give me a list of unique postal code 
14 . Which customer segment is more profitable find it out. 
15 . Try to find out the 10th most loss-making product category. 
16 . Try to find out 10 top products with highest margins

# %%
import pandas as pd
import mysql.connector as con
import csvkit as cs
from sqlalchemy import create_engine

# %%
# Pushing data in SQL

# %%
#First create Database in mysql using--> CREATE DATABASE Superstore;

# Read Excel file
excel_file = r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx'
df_ss = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx')

hostname = 'localhost' 
username = 'root'
password = 'mysql@DS'  
database_name ='superstore'  
port = '3306'

# Create the MySQL engine
engine = create_engine(f'mysql+pymysql://{username}:{password}@{hostname}:{port}/{database_name}')


# Specify the table name in the database
table_name = 'superstore_usa'

# Drop table if exists
engine.execute(f'DROP TABLE IF EXISTS superstore_usa')

# Import the DataFrame into MySQL
df_ss.to_sql(table_name, con=engine, if_exists='replace', index=False)

# Close the database connection
engine.dispose()

# %%
#Table no 2- Superstore Returns in Superstore 
# Read Excel file
excel_file = r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx'
df_ssr = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx', sheet_name = 'Returns')

username = 'root'
password = 'mysql@DS'  
database_name ='superstore'  
port = '3306'

# Create the MySQL engine
engine = create_engine(f'mysql+pymysql://{username}:{password}@{hostname}:{port}/{database_name}')


# Specify the table name in the database
table_name = 'superstore_returns'

# Drop table if exists
engine.execute(f'DROP TABLE IF EXISTS superstore_returns')

# Import the DataFrame into MySQL
df_ssr.to_sql(table_name, con=engine, if_exists='replace', index=False)

# Close the database connection
engine.dispose()

# %%
# Pushing data in Pandas

# %%
df_s = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx')

# %%
df_s
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df_ssr = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx', sheet_name = 'Returns')

# %%
df_ssr
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df_ssu = pd.read_excel(r'C:\Users\Lenovo\Documents\Data Science\Data Science iNeuron\Python\2023\Pandas\Data Set 3\Superstore_USA.xlsx', sheet_name = 'Users')

# %%
len(df_ssr['Order ID'].unique())
# Out:
# 1634

# %%
df_ssu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# Find out how many return that we have received and with a product id

# %%
def status_count(a):
    if a == 'Returned':
        return 1
    else :
        return 0

# %%
status_count('Returned')
# Out:
# 1

# %%
df_ssr['Status_New'] = df_ssr['Status'].apply(status_count)

# %%
df_ssr
# Out:
#       Order ID    Status  Status_New
# 0           65  Returned           1
# 1          612  Returned           1
# 2          614  Returned           1
# 3          678  Returned           1
# 4          710  Returned           1
# ...        ...       ...         ...
# 1629    182681  Returned           1
# 1630    182683  Returned           1
# 1631    182750  Returned           1
# 1632    182781  Returned           1
# 1633    182906  Returned           1
#
# [1634 rows x 3 columns]

# %%
df_ssr.groupby('Order ID')['Status_New'].sum()
# Out:
# Order ID
# 65        1
# 612       1
# 614       1
# 678       1
# 710       1
#          ..
# 182681    1
# 182683    1
# 182750    1
# 182781    1
# 182906    1
# Name: Status_New, Length: 1634, dtype: int64

# %%
returns_count = (df_ssr['Status_New'] == 1).sum()
print("Total number of returns:", returns_count)
# Out:
# Total number of returns: 1634

# %%
len(df_ssr.groupby('Order ID')['Status_New'].sum())
# Out:
# 1634

# %%
#Try to join order and return data both in SQL and pandas

# %%
pd.merge(df_s,df_ssr, on='Order ID', how='inner')
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
pd.merge(df_ss,df_ssr, how = 'right')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0        NaN            NaN       NaN         NaN            NaN          NaN
# 1        NaN            NaN       NaN         NaN            NaN          NaN
# 2        NaN            NaN       NaN         NaN            NaN          NaN
# 3        NaN            NaN       NaN         NaN            NaN          NaN
# 4        NaN            NaN       NaN         NaN            NaN          NaN
# ...      ...            ...       ...         ...            ...          ...
# 1629     NaN            NaN       NaN         NaN            NaN          NaN
# 1630     NaN            NaN       NaN         NaN            NaN          NaN
# 1631     NaN            NaN       NaN         NaN            NaN          NaN
# 1632     NaN            NaN       NaN         NaN            NaN          NaN
# 1633     NaN            NaN       NaN         NaN            NaN          NaN
#
# ...

# %%
df_ssr1 = pd.merge(df_s,df_ssr, how = 'left')

# %%
df_ssr1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   Order Date  Ship Date    Profit  Quantity ordered new    Sales Order ID  \
# ...

# %%
# Try to find out how many unique customer that we have

# %%
df_s['Customer ID'].unique()
# Out:
# array([   2,    3,    5, ..., 3400, 3402, 3403], dtype=int64)

# %%
len(df_s['Customer ID'].unique())
# Out:
# 2703

# %%
df_s['Customer Name'].unique()
# Out:
# array(['Janice Fletcher', 'Bonnie Potter', 'Ronnie Proctor', ...,
#        'Florence Gold', 'Frederick Cole', 'Tammy Buckley'], dtype=object)

# %%
len(df_s['Customer Name'].unique())
# Out:
# 2703

# %%
#Try to find out in how many regions we are saling a product and who is a manager for a respective region

# %%
df_s.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df_s['Region'].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
len(df_s['Region'].unique())
# Out:
# 4

# %%
df_ssu1 = pd.merge(df_s,df_ssu)

# %%
df_ssu1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   24844         Medium      0.09       78.69          19.99           14
# 2   24846         Medium      0.08        3.28           2.31           14
# 3   24847         Medium      0.05        3.28           4.20           14
# 4   24848         Medium      0.05        3.58           1.63           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0    Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
# 2  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
# 3  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
# 4  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df_ssu1[['Region', 'Manager']]
# Out:
#        Region Manager
# 0     Central   Chris
# 1     Central   Chris
# 2     Central   Chris
# 3     Central   Chris
# 4     Central   Chris
# ...       ...     ...
# 9421    South     Sam
# 9422    South     Sam
# 9423    South     Sam
# 9424    South     Sam
# 9425    South     Sam
#
# [9426 rows x 2 columns]

# %%
df_ssu1.groupby('Region') ['Manager'].unique()
# Out:
# Region
# Central      [Chris]
# East          [Erin]
# South          [Sam]
# West       [William]
# Name: Manager, dtype: object

# %%
# Find out how many different shipement mode that we have and what is a percentage usability of all the shipment mode with respect to dataset

# %%
df_s
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df_s['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
ship_mode_count = df_s['Ship Mode'].value_counts()

# %%
ship_mode_count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
total_ship_mode_count = len(df_s['Ship Mode'])

# %%
total_ship_mode_count
# Out:
# 9426

# %%
percentage_usability = (ship_mode_count/total_ship_mode_count)*100

# %%
print ("Percentage Usability of Shipment Modes: ")
print(percentage_usability, "in %")
# Out:
# Percentage Usability of Shipment Modes:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64 in %

# %%
# Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df_s.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df_s['Date_diff'] = df_s['Ship Date']-df_s['Order Date']

# %%
df_s.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
# Based on above question find out for which order id we have shipment duration more than 10 days

# %%
df_s['Date_diff_int'] = df_s['Date_diff'].dt.days.astype(int)

# %%
df_s
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1= df_s[df_s['Date_diff_int']>10]

# %%
df1[['Order ID', 'Date_diff_int']]
# Out:
#       Order ID  Date_diff_int
# 643      87215             84
# 1548     86318             11
# 1549     86318             15
# 1678     87957             17
# 1679     87957             11
# 1680     87957             28
# 1697     19556             17
# 1698     19556             11
# 1699     19556             28
# 2515     86177             92
# 5548     88223             14
# 5673     88352             17
# 5859     87572             22
# 5881     91294             24
# 8607     86434             18
# 8609     86436             17
# 8610     86436             19
# 8973     87300             19
# 8982     19841             27
# 8983     19841             31
# 8993     19841             19
# 8996     87300             27
# 8997     87300             31

# %%
# Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
df_ssr1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   Order Date  Ship Date    Profit  Quantity ordered new    Sales Order ID  \
# ...

# %%
df_ssu
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df_ss1 = pd.merge(df_ssr1,df_ssu)

# %%
df_ss1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   24844         Medium      0.09       78.69          19.99           14
# 2   24846         Medium      0.08        3.28           2.31           14
# 3   24847         Medium      0.05        3.28           4.20           14
# 4   24848         Medium      0.05        3.58           1.63           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0    Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
# 2  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
# 3  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
# 4  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
#
#    Ship Date    Profit Quantity ordered new    Sales Order ID Date_diff  \
# ...

# %%
df2 = df_ss1[df_ss1['Date_diff_int']>15]

# %%
df2.head()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 189    18246       Critical      0.05       11.09           5.25          250
# 3476   20703  Not Specified      0.07      130.98          30.00          637
# 3478   20705  Not Specified      0.08      115.99           4.23          637
# 3495    2703  Not Specified      0.07      130.98          30.00          640
# 3497    2705  Not Specified      0.08      115.99           4.23          640
#
#                 Customer Name       Ship Mode Customer Segment  \
# 189   Brenda Nelson Blanchard     Regular Air        Corporate
# 3476       Christopher Bryant  Delivery Truck         Consumer
# 3478       Christopher Bryant     Regular Air         Consumer
# 3495               Neal Wolfe  Delivery Truck         Consumer
# 3497               Neal Wolfe     Regular Air         Consumer
#
#      Product Category  ...  Ship Date     Profit Quantity ordered new  \
# ...

# %%
df2[df2['Status'] == 'Returned']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Date_diff, Date_diff_int, Status, Status_New, Manager]
# Index: []
#
# [0 rows x 29 columns]

# %%
returned_orders = df_ss1[(df_ss1['Status'] == 'Returned') & (df_ss1['Date_diff_int'] > 15)]
output = returned_orders[['Order ID', 'Date_diff', 'Status', 'Manager']]

# %%
output  # no return entry found for more than 15 days duration
# Out:
# Empty DataFrame
# Columns: [Order ID, Date_diff, Status, Manager]
# Index: []

# %%
#Gorup by region and find out which region is more profitable

# %%
df_ss1.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Date_diff',
#        'Date_diff_int', 'Status', 'Status_New', 'Manager'],
#       dtype='object')

# %%
df_ss1.groupby('Region')['Profit'].sum().sort_values(ascending = False).reset_index()   #Central region
# Out:
#     Region         Profit
# 0  Central  519825.567067
# 1     East  377566.186045
# 2     West  310849.453897
# 3    South  104201.192420

# %%
#Try to find out overalll in which country we are giving more discount

# %%
df_ss1.groupby('Region')['Discount'].sum().sort_values(ascending = False).reset_index()
# Out:
#     Region  Discount
# 0  Central    143.06
# 1     East    114.45
# 2     West    113.75
# 3    South     96.53

# %%
df_ss1.groupby('State or Province')['Discount'].sum().sort_values(ascending = False).head(3).reset_index()
# Out:
#   State or Province  Discount
# 0        California     52.28
# 1             Texas     31.36
# 2          Illinois     29.71

# %%
df_ss1.groupby('City')['Discount'].sum().sort_values(ascending = False).reset_index()
# Out:
#                  City  Discount
# 0         Los Angeles     10.37
# 1       New York City     10.16
# 2             Chicago      4.83
# 3             Seattle      4.47
# 4              Boston      3.79
# ...               ...       ...
# 1419        Billerica      0.00
# 1420  North Kingstown      0.00
# 1421       Toms River      0.00
# 1422            Acton      0.00
# 1423      Wallingford      0.00
#
# [1424 rows x 2 columns]

# %%
#Give me a list of unique postal code

# %%
df_ss1['Postal Code'].unique()
# Out:
# array([60101, 55372, 68005, ..., 30144, 30240, 31204], dtype=int64)

# %%
pd.DataFrame(df_ss1['Postal Code'].unique())
# Out:
#           0
# 0     60101
# 1     55372
# 2     68005
# 3     62002
# 4     75019
# ...     ...
# 1692  37604
# 1693  33614
# 1694  30144
# 1695  30240
# 1696  31204
#
# [1697 rows x 1 columns]

# %%
#City vise postal codes

# %%
Postal_Code_City = df_ss1.groupby('City')['Postal Code'].unique()

# %%
print(Postal_Code_City)
# Out:
# City
# Aberdeen      [57401]
# Abilene       [79605]
# Abington       [2351]
# Acton          [1718]
# Addison       [60101]
#                ...
# York          [17403]
# Youngstown    [44511]
# Yuba City     [95991]
# Yucaipa       [92399]
# Yuma          [85364]
# Name: Postal Code, Length: 1424, dtype: object

# %%
# Which customer segment is more profitable find it out.

# %%
df_ss1.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   24844         Medium      0.09       78.69          19.99           14
# 2   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0    Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1  Gwendolyn F Tyson  Regular Air   Small Business        Furniture  ...
# 2  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies  ...
#
#    Ship Date    Profit Quantity ordered new    Sales Order ID Date_diff  \
# 0 2012-05-30    1.3200                    2     5.90    False    2 days
# 1 2010-05-14  803.4705                   16  1164.45    False    2 days
# 2 2010-05-13  -24.0300                    7    22.23    False    1 days
#
#   Date_diff_int  Status Status_New Manager
# ...

# %%
df_ss1.groupby('Customer Segment')['Profit'].sum().sort_values(ascending = False).reset_index()
# Out:
#   Customer Segment         Profit
# 0        Corporate  505538.627783
# 1   Small Business  316474.592482
# 2      Home Office  283869.553814
# 3         Consumer  206559.625348

# %%
# Try to find out the 10th most loss-making product category.

# %%
df_ss1.groupby('Product Category')['Profit'].sum().sort_values(ascending= False).reset_index()
# Out:
#   Product Category         Profit
# 0       Technology  683097.884748
# 1  Office Supplies  451990.216492
# 2        Furniture  177354.298188

# %%
df_ss1.groupby('Product Category')['Profit'].min().sort_values(ascending= False).reset_index()
# Out:
#   Product Category       Profit
# 0        Furniture -13706.46400
# 1  Office Supplies -14369.12358
# 2       Technology -16476.83800

# %%
# Try to find out 10 top products with highest margins

# %%
df_ss1.groupby('Product Name')['Product Base Margin'].max().sort_values(ascending = False).head(10).reset_index()
# Out:
#                                         Product Name  Product Base Margin
# 0  Office Impressions Heavy Duty Welded Shelving ...                 0.85
# 1                                         Accessory4                 0.85
# 2                  Sterling Rubber Bands by Alliance                 0.85
# 3                   Belkin OmniView SE Rackmount Kit                 0.85
# 4                                        Accessory27                 0.85
# 5  Serrated Blade or Curved Handle Hand Letter Op...                 0.84
# 6  Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...                 0.84
# 7                        Tennsco Commercial Shelving                 0.84
# 8            Carina 42"Hx23 3/4"W Media Storage Unit                 0.83
# 9                                        Accessory29                 0.83
